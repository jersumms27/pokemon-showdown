# %%
with open('pokemon_attributes.txt', 'r') as f:
    attributes = f.read().split('\n')

# %%
from poke_env.player import Player, RandomPlayer

class DebugPlayer(Player):
    def choose_move(self, battle):
        print("=== New turn ===")
        try:
            for attr in attributes:
                print(f'{attr} ({type(battle.active_pokemon.__getattribute__(attr))}): {battle.active_pokemon.__getattribute__(attr)}')
        except:
            pass

        # For now, just act randomly
        return self.choose_random_move(battle)

# %%
async def main():
    p1 = DebugPlayer(battle_format="gen9randombattle")
    p2 = RandomPlayer(battle_format="gen9randombattle")

    await p1.battle_against(p2, n_battles=1)

    print("Finished battle!")
    print("Wins:", p1.n_won_battles)

await main()
# Out:
# === New turn ===
# ability (<class 'str'>): noguard
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): lycanroc
# base_stats (<class 'dict'>): {'atk': 115, 'def': 75, 'hp': 85, 'spa': 55, 'spd': 75, 'spe': 82}
# boost (<class 'method'>): <bound method Pokemon.boost of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': 0, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# current_hp (<class 'int'>): 296
# current_hp_fraction (<class 'float'>): 1.0
# damage (<class 'method'>): <bound method Pokemon.damage of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# faint (<class 'method'>): <bound method Pokemon.faint of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# gender (<enum 'PokemonGender'>): MALE (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# height (<class 'float'>): 1.1
# identifier (<class 'method'>): <bound method Pokemon.identifier of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>): lifeorb
# level (<class 'int'>): 89
# max_hp (<class 'int'>): 296
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# moved (<class 'method'>): <bound method Pokemon.moved of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# moves (<class 'dict'>): {'suckerpunch': suckerpunch (Move object), 'closecombat': closecombat (Move object), 'stoneedge': stoneedge (Move object), 'swordsdance': swordsdance (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Lycanroc
# original_types (<class 'list'>): [<PokemonType.ROCK: 16>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['keeneye', 'vitalspirit', 'noguard']
# prepare (<class 'method'>): <bound method Pokemon.prepare of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): lycanrocmidnight
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# stats (<class 'dict'>): {'hp': 296, 'atk': 255, 'def': 184, 'spa': 149, 'spd': 184, 'spe': 197}
# status (<class 'NoneType'>): None
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# transform (<class 'method'>): <bound method Pokemon.transform of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# type_1 (<enum 'PokemonType'>): ROCK (pokemon type) object
# type_2 (<class 'NoneType'>): None
# types (<class 'list'>): [<PokemonType.ROCK: 16>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# weight (<class 'int'>): 25
# === New turn ===
# ability (<class 'str'>): noguard
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): lycanroc
# base_stats (<class 'dict'>): {'atk': 115, 'def': 75, 'hp': 85, 'spa': 55, 'spd': 75, 'spe': 82}
# boost (<class 'method'>): <bound method Pokemon.boost of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': 0, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# current_hp (<class 'int'>): 296
# current_hp_fraction (<class 'float'>): 1.0
# damage (<class 'method'>): <bound method Pokemon.damage of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# faint (<class 'method'>): <bound method Pokemon.faint of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# gender (<enum 'PokemonGender'>): MALE (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# height (<class 'float'>): 1.1
# identifier (<class 'method'>): <bound method Pokemon.identifier of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>): lifeorb
# level (<class 'int'>): 89
# max_hp (<class 'int'>): 296
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# moved (<class 'method'>): <bound method Pokemon.moved of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# moves (<class 'dict'>): {'suckerpunch': suckerpunch (Move object), 'closecombat': closecombat (Move object), 'stoneedge': stoneedge (Move object), 'swordsdance': swordsdance (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Lycanroc
# original_types (<class 'list'>): [<PokemonType.ROCK: 16>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['keeneye', 'vitalspirit', 'noguard']
# prepare (<class 'method'>): <bound method Pokemon.prepare of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): lycanrocmidnight
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# stats (<class 'dict'>): {'hp': 296, 'atk': 255, 'def': 184, 'spa': 149, 'spd': 184, 'spe': 197}
# status (<class 'NoneType'>): None
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# transform (<class 'method'>): <bound method Pokemon.transform of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# type_1 (<enum 'PokemonType'>): ROCK (pokemon type) object
# type_2 (<class 'NoneType'>): None
# types (<class 'list'>): [<PokemonType.ROCK: 16>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# weight (<class 'int'>): 25
# === New turn ===
# ability (<class 'str'>): noguard
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): lycanroc
# base_stats (<class 'dict'>): {'atk': 115, 'def': 75, 'hp': 85, 'spa': 55, 'spd': 75, 'spe': 82}
# boost (<class 'method'>): <bound method Pokemon.boost of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': 0, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# current_hp (<class 'int'>): 173
# current_hp_fraction (<class 'float'>): 0.5844594594594594
# damage (<class 'method'>): <bound method Pokemon.damage of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# faint (<class 'method'>): <bound method Pokemon.faint of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# gender (<enum 'PokemonGender'>): MALE (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# height (<class 'float'>): 1.1
# identifier (<class 'method'>): <bound method Pokemon.identifier of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>):
# level (<class 'int'>): 89
# max_hp (<class 'int'>): 296
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# moved (<class 'method'>): <bound method Pokemon.moved of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# moves (<class 'dict'>): {'suckerpunch': suckerpunch (Move object), 'closecombat': closecombat (Move object), 'stoneedge': stoneedge (Move object), 'swordsdance': swordsdance (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Lycanroc
# original_types (<class 'list'>): [<PokemonType.ROCK: 16>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['keeneye', 'vitalspirit', 'noguard']
# prepare (<class 'method'>): <bound method Pokemon.prepare of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): lycanrocmidnight
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# stats (<class 'dict'>): {'hp': 296, 'atk': 255, 'def': 184, 'spa': 149, 'spd': 184, 'spe': 197}
# status (<class 'NoneType'>): None
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# transform (<class 'method'>): <bound method Pokemon.transform of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# type_1 (<enum 'PokemonType'>): ROCK (pokemon type) object
# type_2 (<class 'NoneType'>): None
# types (<class 'list'>): [<PokemonType.ROCK: 16>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of lycanrocmidnight (pokemon object) [Active: True, Status: None]>
# weight (<class 'int'>): 25
# === New turn ===
# ability (<class 'str'>): intimidate
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of arcanine (pokemon object) [Active: True, Status: None]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): arcanine
# base_stats (<class 'dict'>): {'atk': 110, 'def': 80, 'hp': 90, 'spa': 100, 'spd': 80, 'spe': 95}
# boost (<class 'method'>): <bound method Pokemon.boost of arcanine (pokemon object) [Active: True, Status: None]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': -1, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of arcanine (pokemon object) [Active: True, Status: None]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of arcanine (pokemon object) [Active: True, Status: None]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of arcanine (pokemon object) [Active: True, Status: None]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of arcanine (pokemon object) [Active: True, Status: None]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of arcanine (pokemon object) [Active: True, Status: None]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of arcanine (pokemon object) [Active: True, Status: None]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of arcanine (pokemon object) [Active: True, Status: None]>
# current_hp (<class 'int'>): 288
# current_hp_fraction (<class 'float'>): 1.0
# damage (<class 'method'>): <bound method Pokemon.damage of arcanine (pokemon object) [Active: True, Status: None]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of arcanine (pokemon object) [Active: True, Status: None]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of arcanine (pokemon object) [Active: True, Status: None]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of arcanine (pokemon object) [Active: True, Status: None]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of arcanine (pokemon object) [Active: True, Status: None]>
# faint (<class 'method'>): <bound method Pokemon.faint of arcanine (pokemon object) [Active: True, Status: None]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of arcanine (pokemon object) [Active: True, Status: None]>
# gender (<enum 'PokemonGender'>): FEMALE (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of arcanine (pokemon object) [Active: True, Status: None]>
# height (<class 'float'>): 1.9
# identifier (<class 'method'>): <bound method Pokemon.identifier of arcanine (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of arcanine (pokemon object) [Active: True, Status: None]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>): heavydutyboots
# level (<class 'int'>): 84
# max_hp (<class 'int'>): 288
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of arcanine (pokemon object) [Active: True, Status: None]>
# moved (<class 'method'>): <bound method Pokemon.moved of arcanine (pokemon object) [Active: True, Status: None]>
# moves (<class 'dict'>): {'roar': roar (Move object), 'flareblitz': flareblitz (Move object), 'morningsun': morningsun (Move object), 'extremespeed': extremespeed (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Arcanine
# original_types (<class 'list'>): [<PokemonType.FIRE: 7>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['intimidate', 'flashfire', 'justified']
# prepare (<class 'method'>): <bound method Pokemon.prepare of arcanine (pokemon object) [Active: True, Status: None]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of arcanine (pokemon object) [Active: True, Status: None]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of arcanine (pokemon object) [Active: True, Status: None]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of arcanine (pokemon object) [Active: True, Status: None]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of arcanine (pokemon object) [Active: True, Status: None]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of arcanine (pokemon object) [Active: True, Status: None]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): arcanine
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of arcanine (pokemon object) [Active: True, Status: None]>
# stats (<class 'dict'>): {'hp': 288, 'atk': 233, 'def': 183, 'spa': 216, 'spd': 183, 'spe': 208}
# status (<class 'NoneType'>): None
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of arcanine (pokemon object) [Active: True, Status: None]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of arcanine (pokemon object) [Active: True, Status: None]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of arcanine (pokemon object) [Active: True, Status: None]>
# transform (<class 'method'>): <bound method Pokemon.transform of arcanine (pokemon object) [Active: True, Status: None]>
# type_1 (<enum 'PokemonType'>): FIRE (pokemon type) object
# type_2 (<class 'NoneType'>): None
# types (<class 'list'>): [<PokemonType.FIRE: 7>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of arcanine (pokemon object) [Active: True, Status: None]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of arcanine (pokemon object) [Active: True, Status: None]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of arcanine (pokemon object) [Active: True, Status: None]>
# weight (<class 'int'>): 155
# === New turn ===
# ability (<class 'str'>): ironfist
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of hitmonchan (pokemon object) [Active: True, Status: None]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): hitmonchan
# base_stats (<class 'dict'>): {'atk': 105, 'def': 79, 'hp': 50, 'spa': 35, 'spd': 110, 'spe': 76}
# boost (<class 'method'>): <bound method Pokemon.boost of hitmonchan (pokemon object) [Active: True, Status: None]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': 0, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of hitmonchan (pokemon object) [Active: True, Status: None]>
# current_hp (<class 'int'>): 229
# current_hp_fraction (<class 'float'>): 1.0
# damage (<class 'method'>): <bound method Pokemon.damage of hitmonchan (pokemon object) [Active: True, Status: None]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of hitmonchan (pokemon object) [Active: True, Status: None]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of hitmonchan (pokemon object) [Active: True, Status: None]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of hitmonchan (pokemon object) [Active: True, Status: None]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of hitmonchan (pokemon object) [Active: True, Status: None]>
# faint (<class 'method'>): <bound method Pokemon.faint of hitmonchan (pokemon object) [Active: True, Status: None]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of hitmonchan (pokemon object) [Active: True, Status: None]>
# gender (<enum 'PokemonGender'>): MALE (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of hitmonchan (pokemon object) [Active: True, Status: None]>
# height (<class 'float'>): 1.4
# identifier (<class 'method'>): <bound method Pokemon.identifier of hitmonchan (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>): leftovers
# level (<class 'int'>): 87
# max_hp (<class 'int'>): 229
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of hitmonchan (pokemon object) [Active: True, Status: None]>
# moved (<class 'method'>): <bound method Pokemon.moved of hitmonchan (pokemon object) [Active: True, Status: None]>
# moves (<class 'dict'>): {'poisonjab': poisonjab (Move object), 'bulkup': bulkup (Move object), 'knockoff': knockoff (Move object), 'drainpunch': drainpunch (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Hitmonchan
# original_types (<class 'list'>): [<PokemonType.FIGHTING: 6>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['keeneye', 'ironfist', 'innerfocus']
# prepare (<class 'method'>): <bound method Pokemon.prepare of hitmonchan (pokemon object) [Active: True, Status: None]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of hitmonchan (pokemon object) [Active: True, Status: None]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of hitmonchan (pokemon object) [Active: True, Status: None]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): hitmonchan
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of hitmonchan (pokemon object) [Active: True, Status: None]>
# stats (<class 'dict'>): {'hp': 229, 'atk': 232, 'def': 187, 'spa': 111, 'spd': 241, 'spe': 182}
# status (<class 'NoneType'>): None
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of hitmonchan (pokemon object) [Active: True, Status: None]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of hitmonchan (pokemon object) [Active: True, Status: None]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of hitmonchan (pokemon object) [Active: True, Status: None]>
# transform (<class 'method'>): <bound method Pokemon.transform of hitmonchan (pokemon object) [Active: True, Status: None]>
# type_1 (<enum 'PokemonType'>): FIGHTING (pokemon type) object
# type_2 (<class 'NoneType'>): None
# types (<class 'list'>): [<PokemonType.FIGHTING: 6>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of hitmonchan (pokemon object) [Active: True, Status: None]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of hitmonchan (pokemon object) [Active: True, Status: None]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of hitmonchan (pokemon object) [Active: True, Status: None]>
# weight (<class 'float'>): 50.2
# === New turn ===
# ability (<class 'str'>): ironfist
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of hitmonchan (pokemon object) [Active: True, Status: None]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): hitmonchan
# base_stats (<class 'dict'>): {'atk': 105, 'def': 79, 'hp': 50, 'spa': 35, 'spd': 110, 'spe': 76}
# boost (<class 'method'>): <bound method Pokemon.boost of hitmonchan (pokemon object) [Active: True, Status: None]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': 0, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of hitmonchan (pokemon object) [Active: True, Status: None]>
# current_hp (<class 'int'>): 178
# current_hp_fraction (<class 'float'>): 0.777292576419214
# damage (<class 'method'>): <bound method Pokemon.damage of hitmonchan (pokemon object) [Active: True, Status: None]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of hitmonchan (pokemon object) [Active: True, Status: None]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of hitmonchan (pokemon object) [Active: True, Status: None]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of hitmonchan (pokemon object) [Active: True, Status: None]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of hitmonchan (pokemon object) [Active: True, Status: None]>
# faint (<class 'method'>): <bound method Pokemon.faint of hitmonchan (pokemon object) [Active: True, Status: None]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of hitmonchan (pokemon object) [Active: True, Status: None]>
# gender (<enum 'PokemonGender'>): MALE (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of hitmonchan (pokemon object) [Active: True, Status: None]>
# height (<class 'float'>): 1.4
# identifier (<class 'method'>): <bound method Pokemon.identifier of hitmonchan (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>):
# level (<class 'int'>): 87
# max_hp (<class 'int'>): 229
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of hitmonchan (pokemon object) [Active: True, Status: None]>
# moved (<class 'method'>): <bound method Pokemon.moved of hitmonchan (pokemon object) [Active: True, Status: None]>
# moves (<class 'dict'>): {'poisonjab': poisonjab (Move object), 'bulkup': bulkup (Move object), 'knockoff': knockoff (Move object), 'drainpunch': drainpunch (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Hitmonchan
# original_types (<class 'list'>): [<PokemonType.FIGHTING: 6>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['keeneye', 'ironfist', 'innerfocus']
# prepare (<class 'method'>): <bound method Pokemon.prepare of hitmonchan (pokemon object) [Active: True, Status: None]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of hitmonchan (pokemon object) [Active: True, Status: None]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of hitmonchan (pokemon object) [Active: True, Status: None]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): hitmonchan
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of hitmonchan (pokemon object) [Active: True, Status: None]>
# stats (<class 'dict'>): {'hp': 229, 'atk': 232, 'def': 187, 'spa': 111, 'spd': 241, 'spe': 182}
# status (<class 'NoneType'>): None
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of hitmonchan (pokemon object) [Active: True, Status: None]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of hitmonchan (pokemon object) [Active: True, Status: None]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of hitmonchan (pokemon object) [Active: True, Status: None]>
# transform (<class 'method'>): <bound method Pokemon.transform of hitmonchan (pokemon object) [Active: True, Status: None]>
# type_1 (<enum 'PokemonType'>): FIGHTING (pokemon type) object
# type_2 (<class 'NoneType'>): None
# types (<class 'list'>): [<PokemonType.FIGHTING: 6>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of hitmonchan (pokemon object) [Active: True, Status: None]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of hitmonchan (pokemon object) [Active: True, Status: None]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of hitmonchan (pokemon object) [Active: True, Status: None]>
# weight (<class 'float'>): 50.2
# === New turn ===
# ability (<class 'str'>): ironfist
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of hitmonchan (pokemon object) [Active: True, Status: None]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): hitmonchan
# base_stats (<class 'dict'>): {'atk': 105, 'def': 79, 'hp': 50, 'spa': 35, 'spd': 110, 'spe': 76}
# boost (<class 'method'>): <bound method Pokemon.boost of hitmonchan (pokemon object) [Active: True, Status: None]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': 1, 'def': 1, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of hitmonchan (pokemon object) [Active: True, Status: None]>
# current_hp (<class 'int'>): 157
# current_hp_fraction (<class 'float'>): 0.6855895196506551
# damage (<class 'method'>): <bound method Pokemon.damage of hitmonchan (pokemon object) [Active: True, Status: None]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of hitmonchan (pokemon object) [Active: True, Status: None]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of hitmonchan (pokemon object) [Active: True, Status: None]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of hitmonchan (pokemon object) [Active: True, Status: None]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of hitmonchan (pokemon object) [Active: True, Status: None]>
# faint (<class 'method'>): <bound method Pokemon.faint of hitmonchan (pokemon object) [Active: True, Status: None]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of hitmonchan (pokemon object) [Active: True, Status: None]>
# gender (<enum 'PokemonGender'>): MALE (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of hitmonchan (pokemon object) [Active: True, Status: None]>
# height (<class 'float'>): 1.4
# identifier (<class 'method'>): <bound method Pokemon.identifier of hitmonchan (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of hitmonchan (pokemon object) [Active: True, Status: None]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>):
# level (<class 'int'>): 87
# max_hp (<class 'int'>): 229
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of hitmonchan (pokemon object) [Active: True, Status: None]>
# moved (<class 'method'>): <bound method Pokemon.moved of hitmonchan (pokemon object) [Active: True, Status: None]>
# moves (<class 'dict'>): {'poisonjab': poisonjab (Move object), 'bulkup': bulkup (Move object), 'knockoff': knockoff (Move object), 'drainpunch': drainpunch (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Hitmonchan
# original_types (<class 'list'>): [<PokemonType.FIGHTING: 6>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['keeneye', 'ironfist', 'innerfocus']
# prepare (<class 'method'>): <bound method Pokemon.prepare of hitmonchan (pokemon object) [Active: True, Status: None]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of hitmonchan (pokemon object) [Active: True, Status: None]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of hitmonchan (pokemon object) [Active: True, Status: None]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of hitmonchan (pokemon object) [Active: True, Status: None]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): hitmonchan
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of hitmonchan (pokemon object) [Active: True, Status: None]>
# stats (<class 'dict'>): {'hp': 229, 'atk': 232, 'def': 187, 'spa': 111, 'spd': 241, 'spe': 182}
# status (<class 'NoneType'>): None
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of hitmonchan (pokemon object) [Active: True, Status: None]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of hitmonchan (pokemon object) [Active: True, Status: None]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of hitmonchan (pokemon object) [Active: True, Status: None]>
# transform (<class 'method'>): <bound method Pokemon.transform of hitmonchan (pokemon object) [Active: True, Status: None]>
# type_1 (<enum 'PokemonType'>): FIGHTING (pokemon type) object
# type_2 (<class 'NoneType'>): None
# types (<class 'list'>): [<PokemonType.FIGHTING: 6>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of hitmonchan (pokemon object) [Active: True, Status: None]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of hitmonchan (pokemon object) [Active: True, Status: None]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of hitmonchan (pokemon object) [Active: True, Status: None]>
# weight (<class 'float'>): 50.2
# === New turn ===
# ability (<class 'str'>): flamebody
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of moltres (pokemon object) [Active: True, Status: None]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): moltres
# base_stats (<class 'dict'>): {'atk': 100, 'def': 90, 'hp': 90, 'spa': 125, 'spd': 85, 'spe': 90}
# boost (<class 'method'>): <bound method Pokemon.boost of moltres (pokemon object) [Active: True, Status: None]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': 0, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of moltres (pokemon object) [Active: True, Status: None]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of moltres (pokemon object) [Active: True, Status: None]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of moltres (pokemon object) [Active: True, Status: None]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of moltres (pokemon object) [Active: True, Status: None]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of moltres (pokemon object) [Active: True, Status: None]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of moltres (pokemon object) [Active: True, Status: None]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of moltres (pokemon object) [Active: True, Status: None]>
# current_hp (<class 'int'>): 278
# current_hp_fraction (<class 'float'>): 1.0
# damage (<class 'method'>): <bound method Pokemon.damage of moltres (pokemon object) [Active: True, Status: None]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of moltres (pokemon object) [Active: True, Status: None]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of moltres (pokemon object) [Active: True, Status: None]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of moltres (pokemon object) [Active: True, Status: None]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of moltres (pokemon object) [Active: True, Status: None]>
# faint (<class 'method'>): <bound method Pokemon.faint of moltres (pokemon object) [Active: True, Status: None]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of moltres (pokemon object) [Active: True, Status: None]>
# gender (<enum 'PokemonGender'>): NEUTRAL (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of moltres (pokemon object) [Active: True, Status: None]>
# height (<class 'int'>): 2
# identifier (<class 'method'>): <bound method Pokemon.identifier of moltres (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of moltres (pokemon object) [Active: True, Status: None]>
# ...
# identifier (<class 'method'>): <bound method Pokemon.identifier of swanna (pokemon object) [Active: True, Status: None]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of swanna (pokemon object) [Active: True, Status: None]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>):
# level (<class 'int'>): 89
# max_hp (<class 'int'>): 278
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of swanna (pokemon object) [Active: True, Status: None]>
# moved (<class 'method'>): <bound method Pokemon.moved of swanna (pokemon object) [Active: True, Status: None]>
# moves (<class 'dict'>): {'roost': roost (Move object), 'bravebird': bravebird (Move object), 'hydropump': hydropump (Move object), 'defog': defog (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Swanna
# original_types (<class 'list'>): [<PokemonType.WATER: 18>, <PokemonType.FLYING: 8>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['keeneye', 'bigpecks', 'hydration']
# prepare (<class 'method'>): <bound method Pokemon.prepare of swanna (pokemon object) [Active: True, Status: None]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of swanna (pokemon object) [Active: True, Status: None]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of swanna (pokemon object) [Active: True, Status: None]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of swanna (pokemon object) [Active: True, Status: None]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of swanna (pokemon object) [Active: True, Status: None]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of swanna (pokemon object) [Active: True, Status: None]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): swanna
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of swanna (pokemon object) [Active: True, Status: None]>
# stats (<class 'dict'>): {'hp': 278, 'atk': 206, 'def': 163, 'spa': 206, 'spd': 163, 'spe': 225}
# status (<class 'NoneType'>): None
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of swanna (pokemon object) [Active: True, Status: None]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of swanna (pokemon object) [Active: True, Status: None]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of swanna (pokemon object) [Active: True, Status: None]>
# transform (<class 'method'>): <bound method Pokemon.transform of swanna (pokemon object) [Active: True, Status: None]>
# type_1 (<enum 'PokemonType'>): WATER (pokemon type) object
# type_2 (<enum 'PokemonType'>): FLYING (pokemon type) object
# types (<class 'list'>): [<PokemonType.WATER: 18>, <PokemonType.FLYING: 8>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of swanna (pokemon object) [Active: True, Status: None]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of swanna (pokemon object) [Active: True, Status: None]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of swanna (pokemon object) [Active: True, Status: None]>
# weight (<class 'float'>): 24.2
# === New turn ===
# ability (<class 'str'>): hydration
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of swanna (pokemon object) [Active: True, Status: FNT]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): swanna
# base_stats (<class 'dict'>): {'atk': 87, 'def': 63, 'hp': 75, 'spa': 87, 'spd': 63, 'spe': 98}
# boost (<class 'method'>): <bound method Pokemon.boost of swanna (pokemon object) [Active: True, Status: FNT]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': -1, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of swanna (pokemon object) [Active: True, Status: FNT]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of swanna (pokemon object) [Active: True, Status: FNT]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of swanna (pokemon object) [Active: True, Status: FNT]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of swanna (pokemon object) [Active: True, Status: FNT]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of swanna (pokemon object) [Active: True, Status: FNT]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of swanna (pokemon object) [Active: True, Status: FNT]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of swanna (pokemon object) [Active: True, Status: FNT]>
# current_hp (<class 'int'>): 0
# current_hp_fraction (<class 'int'>): 0
# damage (<class 'method'>): <bound method Pokemon.damage of swanna (pokemon object) [Active: True, Status: FNT]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of swanna (pokemon object) [Active: True, Status: FNT]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of swanna (pokemon object) [Active: True, Status: FNT]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of swanna (pokemon object) [Active: True, Status: FNT]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of swanna (pokemon object) [Active: True, Status: FNT]>
# faint (<class 'method'>): <bound method Pokemon.faint of swanna (pokemon object) [Active: True, Status: FNT]>
# fainted (<class 'bool'>): True
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of swanna (pokemon object) [Active: True, Status: FNT]>
# gender (<enum 'PokemonGender'>): MALE (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of swanna (pokemon object) [Active: True, Status: FNT]>
# height (<class 'float'>): 1.3
# identifier (<class 'method'>): <bound method Pokemon.identifier of swanna (pokemon object) [Active: True, Status: FNT]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of swanna (pokemon object) [Active: True, Status: FNT]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): False
# item (<class 'str'>):
# level (<class 'int'>): 89
# max_hp (<class 'int'>): 278
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of swanna (pokemon object) [Active: True, Status: FNT]>
# moved (<class 'method'>): <bound method Pokemon.moved of swanna (pokemon object) [Active: True, Status: FNT]>
# moves (<class 'dict'>): {'roost': roost (Move object), 'bravebird': bravebird (Move object), 'hydropump': hydropump (Move object), 'defog': defog (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Swanna
# original_types (<class 'list'>): [<PokemonType.WATER: 18>, <PokemonType.FLYING: 8>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['keeneye', 'bigpecks', 'hydration']
# prepare (<class 'method'>): <bound method Pokemon.prepare of swanna (pokemon object) [Active: True, Status: FNT]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of swanna (pokemon object) [Active: True, Status: FNT]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of swanna (pokemon object) [Active: True, Status: FNT]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of swanna (pokemon object) [Active: True, Status: FNT]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of swanna (pokemon object) [Active: True, Status: FNT]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of swanna (pokemon object) [Active: True, Status: FNT]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): swanna
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of swanna (pokemon object) [Active: True, Status: FNT]>
# stats (<class 'dict'>): {'hp': 278, 'atk': 206, 'def': 163, 'spa': 206, 'spd': 163, 'spe': 225}
# status (<enum 'Status'>): FNT (status) object
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of swanna (pokemon object) [Active: True, Status: FNT]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of swanna (pokemon object) [Active: True, Status: FNT]>
# tera_type (<class 'NoneType'>): None
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of swanna (pokemon object) [Active: True, Status: FNT]>
# transform (<class 'method'>): <bound method Pokemon.transform of swanna (pokemon object) [Active: True, Status: FNT]>
# type_1 (<enum 'PokemonType'>): WATER (pokemon type) object
# type_2 (<enum 'PokemonType'>): FLYING (pokemon type) object
# types (<class 'list'>): [<PokemonType.WATER: 18>, <PokemonType.FLYING: 8>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of swanna (pokemon object) [Active: True, Status: FNT]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of swanna (pokemon object) [Active: True, Status: FNT]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of swanna (pokemon object) [Active: True, Status: FNT]>
# weight (<class 'float'>): 24.2
# === New turn ===
# ability (<class 'str'>): flamebody
# active (<class 'bool'>): True
# available_moves_from_request (<class 'method'>): <bound method Pokemon.available_moves_from_request of moltres (pokemon object) [Active: True, Status: PSN]>
# available_z_moves (<class 'list'>): []
# base_species (<class 'str'>): moltres
# base_stats (<class 'dict'>): {'atk': 100, 'def': 90, 'hp': 90, 'spa': 125, 'spd': 85, 'spe': 90}
# boost (<class 'method'>): <bound method Pokemon.boost of moltres (pokemon object) [Active: True, Status: PSN]>
# boosts (<class 'dict'>): {'accuracy': 0, 'atk': 0, 'def': 0, 'evasion': 0, 'spa': 0, 'spd': 0, 'spe': 0}
# cant_move (<class 'method'>): <bound method Pokemon.cant_move of moltres (pokemon object) [Active: True, Status: PSN]>
# clear_active (<class 'method'>): <bound method Pokemon.clear_active of moltres (pokemon object) [Active: True, Status: PSN]>
# clear_boosts (<class 'method'>): <bound method Pokemon.clear_boosts of moltres (pokemon object) [Active: True, Status: PSN]>
# clear_negative_boosts (<class 'method'>): <bound method Pokemon.clear_negative_boosts of moltres (pokemon object) [Active: True, Status: PSN]>
# clear_positive_boosts (<class 'method'>): <bound method Pokemon.clear_positive_boosts of moltres (pokemon object) [Active: True, Status: PSN]>
# copy_boosts (<class 'method'>): <bound method Pokemon.copy_boosts of moltres (pokemon object) [Active: True, Status: PSN]>
# cure_status (<class 'method'>): <bound method Pokemon.cure_status of moltres (pokemon object) [Active: True, Status: PSN]>
# current_hp (<class 'int'>): 75
# current_hp_fraction (<class 'float'>): 0.2697841726618705
# damage (<class 'method'>): <bound method Pokemon.damage of moltres (pokemon object) [Active: True, Status: PSN]>
# damage_multiplier (<class 'method'>): <bound method Pokemon.damage_multiplier of moltres (pokemon object) [Active: True, Status: PSN]>
# effects (<class 'dict'>): {}
# end_effect (<class 'method'>): <bound method Pokemon.end_effect of moltres (pokemon object) [Active: True, Status: PSN]>
# end_item (<class 'method'>): <bound method Pokemon.end_item of moltres (pokemon object) [Active: True, Status: PSN]>
# end_turn (<class 'method'>): <bound method Pokemon.end_turn of moltres (pokemon object) [Active: True, Status: PSN]>
# faint (<class 'method'>): <bound method Pokemon.faint of moltres (pokemon object) [Active: True, Status: PSN]>
# fainted (<class 'bool'>): False
# first_turn (<class 'bool'>): True
# forme_change (<class 'method'>): <bound method Pokemon.forme_change of moltres (pokemon object) [Active: True, Status: PSN]>
# gender (<enum 'PokemonGender'>): NEUTRAL (pokemon gender) object
# heal (<class 'method'>): <bound method Pokemon.heal of moltres (pokemon object) [Active: True, Status: PSN]>
# height (<class 'int'>): 2
# identifier (<class 'method'>): <bound method Pokemon.identifier of moltres (pokemon object) [Active: True, Status: PSN]>
# invert_boosts (<class 'method'>): <bound method Pokemon.invert_boosts of moltres (pokemon object) [Active: True, Status: PSN]>
# is_dynamaxed (<class 'bool'>): False
# is_terastallized (<class 'bool'>): True
# item (<class 'str'>):
# level (<class 'int'>): 81
# max_hp (<class 'int'>): 278
# mega_evolve (<class 'method'>): <bound method Pokemon.mega_evolve of moltres (pokemon object) [Active: True, Status: PSN]>
# moved (<class 'method'>): <bound method Pokemon.moved of moltres (pokemon object) [Active: True, Status: PSN]>
# moves (<class 'dict'>): {'bravebird': bravebird (Move object), 'scorchingsands': scorchingsands (Move object), 'roost': roost (Move object), 'fireblast': fireblast (Move object)}
# must_recharge (<class 'bool'>): False
# name (<class 'str'>): Moltres
# original_types (<class 'list'>): [<PokemonType.FIRE: 7>, <PokemonType.FLYING: 8>]
# pokeball (<class 'str'>): pokeball
# possible_abilities (<class 'list'>): ['pressure', 'flamebody']
# prepare (<class 'method'>): <bound method Pokemon.prepare of moltres (pokemon object) [Active: True, Status: PSN]>
# preparing (<class 'bool'>): False
# preparing_move (<class 'NoneType'>): None
# preparing_target (<class 'NoneType'>): None
# primal (<class 'method'>): <bound method Pokemon.primal of moltres (pokemon object) [Active: True, Status: PSN]>
# protect_counter (<class 'int'>): 0
# revealed (<class 'bool'>): True
# set_boost (<class 'method'>): <bound method Pokemon.set_boost of moltres (pokemon object) [Active: True, Status: PSN]>
# set_hp (<class 'method'>): <bound method Pokemon.set_hp of moltres (pokemon object) [Active: True, Status: PSN]>
# set_hp_status (<class 'method'>): <bound method Pokemon.set_hp_status of moltres (pokemon object) [Active: True, Status: PSN]>
# set_temporary_ability (<class 'method'>): <bound method Pokemon.set_temporary_ability of moltres (pokemon object) [Active: True, Status: PSN]>
# shiny (<class 'bool'>): False
# species (<class 'str'>): moltres
# stab_multiplier (<class 'float'>): 1.5
# start_effect (<class 'method'>): <bound method Pokemon.start_effect of moltres (pokemon object) [Active: True, Status: PSN]>
# stats (<class 'dict'>): {'hp': 278, 'atk': 209, 'def': 192, 'spa': 249, 'spd': 184, 'spe': 192}
# status (<enum 'Status'>): PSN (status) object
# status_counter (<class 'int'>): 0
# switch_in (<class 'method'>): <bound method Pokemon.switch_in of moltres (pokemon object) [Active: True, Status: PSN]>
# switch_out (<class 'method'>): <bound method Pokemon.switch_out of moltres (pokemon object) [Active: True, Status: PSN]>
# tera_type (<enum 'PokemonType'>): GROUND (pokemon type) object
# terastallize (<class 'method'>): <bound method Pokemon.terastallize of moltres (pokemon object) [Active: True, Status: PSN]>
# transform (<class 'method'>): <bound method Pokemon.transform of moltres (pokemon object) [Active: True, Status: PSN]>
# type_1 (<enum 'PokemonType'>): GROUND (pokemon type) object
# type_2 (<class 'NoneType'>): None
# types (<class 'list'>): [<PokemonType.GROUND: 11>]
# update_from_request (<class 'method'>): <bound method Pokemon.update_from_request of moltres (pokemon object) [Active: True, Status: PSN]>
# used_z_move (<class 'method'>): <bound method Pokemon.used_z_move of moltres (pokemon object) [Active: True, Status: PSN]>
# was_illusioned (<class 'method'>): <bound method Pokemon.was_illusioned of moltres (pokemon object) [Active: True, Status: PSN]>
# weight (<class 'int'>): 60
# Finished battle!
# Wins: 1
